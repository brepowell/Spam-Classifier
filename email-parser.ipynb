# %%
##################################################################################################################
#                
#                           Email Parser : Sends Features to CSV or print
#
##################################################################################################################

# import modules
import os
import csv
from email.parser import BytesParser, Parser
from email.policy import default

#path
emails = 'data'

def send_email_features_to_csv():
    with open('email_features.csv', 'w', newline='') as fp:
        writer = csv.writer(fp)
        
        # header row
        writer.writerow(["Subject", "To", "From", "Date", "CC", "BCC", "Message ID", 
                     "In Reply To", "References", "Reply To", "Sender", "Received", 
                     "Content Type", "Content Encoding", "Content Disposition", "Body", "Body Length"])
        
        # define max & count
        max = 19000
        count = 0
        for filename in os.listdir(emails):
            try:
                if ((count < max) and filename.endswith('.txt')):
                    # read each file as binary 
                    with open(os.path.join(emails, filename), 'rb') as fp:

                        # define message object
                        msg = BytesParser(policy=default).parse(fp)

                        # parse features
                        subject_ = msg.get('subject')
                        to_ = msg.get('to')
                        from_ = msg.get('from')
                        date_ = msg.get('date')

                        cc_ = msg.get('cc')
                        bcc_ = msg.get('bcc')
                        message_id_ = msg.get('message-id')
                        in_reply_to_ = msg.get('in-reply-to')

                        references_ = msg.get('references')
                        reply_to_ = msg.get('reply-to')
                        sender_ = msg.get('sender')
                        received_ = msg.get('received')

                        content_type_ = msg.get('content-type')
                        content_encoding_ = msg.get('content-encoding')
                        content_disposition_ = msg.get('content-disposition')
                        
                        # msg = BytesParser(policy=default).parse(fp)
                        body_ = msg.get_body(preferencelist=('plain')).get_content()
                        body_length_ = len(body_)

                        # Write the row to the csv file
                        writer.writerow([subject_, to_, from_, date_, cc_, bcc_, 
                                         message_id_, in_reply_to_, references_, 
                                         reply_to_, sender_, received_, content_type_, 
                                         content_encoding_, content_disposition_, body_, body_length_])
                        count+=1
            except:
                pass

def print_email_features():
    # define max & count
    max = 100
    count = 0
    for filename in os.listdir(emails):
        if ((count < max) and filename.endswith('.txt')):
            # read each file as binary 
            with open(os.path.join(emails, filename), 'rb') as fp:

                # define message object
                msg = BytesParser(policy=default).parse(fp)

                # parse features
                subject_ = msg.get('subject')
                to_ = msg.get('to')
                from_ = msg.get('from')
                date_ = msg.get('date')

                cc_ = msg.get('cc')
                bcc_ = msg.get('bcc')
                message_id_ = msg.get('message-id')
                in_reply_to_ = msg.get('in-reply-to')

                references_ = msg.get('references')
                reply_to_ = msg.get('reply-to')
                sender_ = msg.get('sender')
                received_ = msg.get('received')

                content_type_ = msg.get('content-type')
                content_encoding_ = msg.get('content-encoding')
                content_disposition_ = msg.get('content-disposition')

                #  print
                print('Subject: {}'.format(subject_))
                print('To: {}'.format(to_))
                print('From: {}'.format(from_))
                print('Date: {}'.format(date_))

                print('CC: {}'.format(cc_))
                print('BCC: {}'.format(bcc_))
                print('Message ID: {}'.format(message_id_))
                print('In Reply To: {}'.format(in_reply_to_))

                print('References: {}'.format(references_))
                print('Reply To: {}'.format(reply_to_))
                print('Sender: {}'.format(sender_))
                print('Received: {}'.format(received_))

                print('Content Type: {}'.format(content_type_))
                print('Content Encoding: {}'.format(content_encoding_))
                print('Content Disposition: {}'.format(content_disposition_))
                print('\n')
                count+=1

# %%
send_email_features_to_csv()
print_email_features()
# Out:
# Subject: Tinnitus: When The Ringing Won't Stop, Do This For Instant Relief...
# To: bruce@untroubled.org
# From: Escape Tinnitus in less than 21 days! <EscapeTinnitusinlessthan21days@jargate.com>
# Date: Mon, 18 May 2020 17:52:34 +0000
# CC: None
# BCC: None
# Message ID: <cce10930-2669-4118-b205-8c8048ee37c5@jargate.com>
# In Reply To: None
# References: None
# Reply To: EscapeTinnitusinlessthan21days@jargate.com
# Sender: None
# Received: (qmail 2735535 invoked from network); 18 May 2020 17:57:57 -0000
# Content Type: multipart/alternative; boundary="-_-_-8ebfd31f76fc726297__7ce905d3_-_-"; charset="UTF-8"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: The Tiny, Discreet, Extra small size Video Recorder!
# To: bruce@untroubled.org
# From: SmartCam <smartcam@thrusttransfer.co>
# Date: Fri, 29 Apr 2022 16:32:37 -0500
# CC: None
# BCC: None
# Message ID:  <wKVHK_PkABaMrnyn6ifjOcWRqNxbWfEFXhEpA8YVPA4.k-saOjQp8N54xFm9QIQ6zs91PxphIYsp8KlVL1RQ1k8@thrusttransfer.co>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 832258 invoked from network); 29 Apr 2022 21:42:30 -0000
# Content Type: text/html; charset="ISO-8859-1"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Perfect Night Vision Anywhere, Anytime
# To: bruce@untroubled.org
# From: NightBuddy Camping <nightbuddy_camping@cuountycir.com>
# Date: Wed, 13 Apr 2022 17:45:26 -0400
# CC: None
# BCC: None
# Message ID: <0.0.0.28.1D84F7FC910974A.65F91B@mail.cuountycir.com>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 461038 invoked from network); 13 Apr 2022 21:52:55 -0000
# Content Type: multipart/alternative; boundary="----=_Part_364_1567309568.1649886308721"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: 貴方の通信費は全額支払っておきましたので、貴方は今「完全無料」でメールのやり取りが出来る状態になってます。貴方に《現金2億円》を差し上げますので、貴方の口座情報【銀行名/支店名/口座種別/口座番号/口座名義人名】を私に送っていただけますでしょうか？
# To: bruce@bruce-guenter.dyndns.org
# From: お知らせ <mailmaster@wt327jp6.com>
# Date: Mon, 02 Apr 2018 23:31:00 +0900
# CC: None
# BCC: None
# Message ID: <2ecce810a6768437e0c00db205e6e17479246ac6>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 11423 invoked from network); 2 Apr 2018 14:31:02 -0000
# Content Type: text/html; charset="utf-8"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Want to save? Discover How A Mortgage Refinance Could Put Potentially $ Back In Your Pocket Today!
# To: bruce@untroubled.org
# From: Choose Your Mortgage <choose-your-mortgage@fabraswo.com>
# Date: Sat, 19 Feb 2022 14:16:05 -0500
# CC: None
# BCC: None
# Message ID: <0.0.0.7.1D825C52491BB1A.C1B97@mail.fabraswo.com>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: by mail.fabraswo.com id h253380001gf for <bruce@untroubled.org>; Sat, 19 Feb 2022 14:16:05 -0500 (envelope-from <choose-your-mortgage-bruce=untroubled.org@fabraswo.com>)
# Content Type: multipart/alternative; boundary="----=_Part_64_384665757.1645298150967"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: See Drone X Pro in action
# To: bruce@untroubled.org
# From: Drone X <cruel@gnuyf.offensewaterfallfly.co>
# Date: Sun, 16 Jan 2022 02:20:55 -0500
# CC: None
# BCC: None
# Message ID:  <ABvt4e75agnnxHGJ9ucaArF248K-Hi51mDws_hSt5-o._aYcJH3MTPnPR34ufiqAHreKX7sDrjUSVljg1yYhuog@gnuyf.offensewaterfallfly.co>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 602563 invoked from network); 16 Jan 2022 07:33:23 -0000
# Content Type: text/html; charset="ISO-8859-1"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Reduces the look of uneven and sagging skin.
# To: bruce@untroubled.org
# From: Removing Puffiness <RemovingPuffiness@memomex.co>
# Date: Sat, 22 Jan 2022 05:42:08 -0500
# CC: None
# BCC: None
# Message ID: <524mo9fggkh5xyof-e5ryrt788bnul44s-252e-381@memomex.co>
# In Reply To: None
# References: None
# Reply To: Brighten Skin <RemovingPuffiness@memomex.co>
# Sender: None
# Received: None
# Content Type: multipart/alternative; boundary="6c880e88d06d2a3fe4d3421abb4419c1_252e_381"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Account disabled
# To: lists-svn-users@bruce-guenter.dyndns.org
# From: no_answer@bruce-guenter.dyndns.org
# Date: Sat, 30 Apr 2016 -1:24:39 -0600
# CC: None
# BCC: None
# Message ID: <57244197.8000105@bruce-guenter.dyndns.org>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 2753 invoked from network); 30 Apr 2016 22:29:31 -0000
# Content Type: multipart/alternative; boundary="------------090600000801030703050905"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: RE: Invitation to Project Monitoring and Evaluation with Data Management and Analysis Workshop Feb 2023
# To: "bruceg@untroubled.org" <bruceg@untroubled.org>
# From: FOSCORE DEVELOPMENT CENTER <workshops@foscoredevelopmentcenter.org>
# Date: Mon, 16 Jan 2023 18:25:13 +0000
# CC: None
# BCC: None
# Message ID:  <4uixrjoy5x2p.kI9KsnMQo6MGaYPagGYtpw2@email.foscoredevelopmentcenter.org>
# In Reply To: None
# References: None
# Reply To: workshops@foscoredevelopmentcenter.org
# Sender: workshops@foscoredevelopmentcenter.org
# Received: (qmail 421789 invoked from network); 16 Jan 2023 18:25:22 -0000
# Content Type: multipart/alternative; boundary="=-eZCfD0uM1TbCCvaRPOQIaBDx0wNF7Oo123WKzQ=="
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Get Concealed Carry certification
# To: bruce@untroubled.org
# From: US Concealed Online <us_concealed_online@nwwridord.com>
# Date: Sat, 12 Mar 2022 17:39:32 -0500
# CC: None
# BCC: None
# Message ID: <0.0.0.23.1D836620AB01DD8.A3BA12@mail.nwwridord.com>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 73352 invoked from network); 12 Mar 2022 22:49:04 -0000
# Content Type: multipart/alternative; boundary="----=_Part_319_848845545.1647124763783"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Bath Remodeling This Labor Day
# To: bruce@untroubled.org
# From: Bathroom Remodel <bathroom-remodel@wrldofwhp.com>
# Date: Thu, 17 Feb 2022 19:40:08 -0500
# CC: None
# BCC: None
# Message ID: <0.0.0.32.1D82460148C8A94.617EF@mail.wrldofwhp.com>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 92134 invoked from network); 18 Feb 2022 00:46:32 -0000
# Content Type: multipart/alternative; boundary="----=_Part_457_550522099.1645144797115"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Don't let expensive home repair bills stomp out your budget
# To: celestiaslo214@gmail.com
# From: Home Warranty Offer! <ucontactusbackplss@acrossborders.site>
# Date: Tue, 17 Jan 2023 16:42:13 +0100
# CC: None
# BCC: None
# Message ID: <_eQheVh47WErluIXjFKIcg.0@notifications.google.com>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: from google.com (google.com.  172.217.13.78)
# Content Type: text/html
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Burn Fat
# To: bruce@untroubled.org
# From: Worlds Healthiest Bread <KetoBreads@healthpluss.buzz>
# Date: Wed, 13 Apr 2022 03:50:36 -0700
# CC: None
# BCC: None
# Message ID: <gum1tt4ngcqsvq23-h3rjhnkuuef5haxe-12707-fce1@healthpluss.buzz>
# In Reply To: None
# References: None
# Reply To: Keto Desserts <KetoBreads@healthpluss.buzz>
# Sender: None
# Received: None
# Content Type: multipart/alternative; boundary="b11382434e69f4cc328a5dfcd175d979_12707_fce1"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Hi,
# To: None
# From: "Attorney at Law. (Vladimir POPOV)" <Vladimir.POPOV@moz.ac.at>
# Date: Thu, 13 Jan 2022 02:59:33 +0100
# CC: None
# BCC: None
# Message ID: <61DF8785020000C400062D78@gwia01.moz.ac.at>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 531862 invoked from network); 13 Jan 2022 02:06:16 -0000
# Content Type: text/plain; charset="US-ASCII"
# Content Encoding: None
# Content Disposition: inline
#
#
# Subject: Erinnerst du dich an morgen?
# To: Hadlee <bruce@untroubled.org>
# From: Hadlee <ToddMiller@3s.pl>
# Date: Wed, 06 May 2020 19:11:53 -0700
# CC: None
# BCC: None
# Message ID: <FC9C06D3.00A6300D@3s.pl>
# In Reply To: None
# References: None
# Reply To: Hadlee <ToddMiller@3s.pl>
# Sender: None
# Received: from unknown (150.214.235.181)	by qnx.mdrost.com with SMTP; Wed, 06 May 2020 19:52:46 -0700
# Content Type: text/html; charset="iso-8859-1"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Tense This Muscle For 1 Min To Unlock Massive Growth
# To: bruce@untroubled.org
# From: Primal Grow Pro <PrimalGrowPro@feverow.bid>
# Date: Tue, 05 May 2020 12:23:17 -0400
# CC: None
# BCC: None
# Message ID: <1t8kwfpv0kg2uwnf-cv9icy1r8far3bgo-ba6-14e16@feverow.bid>
# In Reply To: None
# References: None
# Reply To: Primal Grow Pro <PrimalGrowPro@feverow.bid>
# Sender: None
# Received: None
# Content Type: multipart/alternative; boundary="914603d5cb1a8bb7a4fc16a7e53a1e8d_ba6_14e16"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Do This Immediately if You Have Enlarged Prostate (Watch)
# To: bruce@untroubled.org
# From: "Vital Flow (Prostate)" <error@wildgo.co>
# Date: Wed, 13 Apr 2022 14:42:32 -0500
# CC: None
# BCC: None
# Message ID:  <IZ27VctMcapMfvHSVUpPH3x8jW7OggwH1_8WbCruJGo.hfD4IfgMfjXkT5bsKkaZUxLSUjv7_RFiUl0Io5vtEuk@wildgo.co>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 459639 invoked from network); 13 Apr 2022 19:46:53 -0000
# Content Type: text/html; charset="ISO-8859-1"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Best Wireless Earphones for your Android/ios device!
# To: bruce@untroubled.org
# From: Smart Gadget <line@haltfax.icu>
# Date: Thu, 07 May 2020 08:31:41 -0500
# CC: None
# BCC: None
# Message ID: <fIi4WPHYRZFmH3CTEaAmGORKrHHziyhGTypUt9PtGEo.4YUErLI9FMsiR-iMftrppsmw4bB6491NohKgopK95GA@haltfax.icu>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 806922 invoked from network); 7 May 2020 13:35:33 -0000
# Content Type: multipart/alternative; boundary="------------54397488537876883340964"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Confirmed: Your Dollar General Reward @ no cost!
# To: bruce@untroubled.org
# From: Family Savings <ShopperDealsDirect@nitrileanex.one>
# Date: Fri, 04 Mar 2022 06:25:25 -0500
# CC: None
# BCC: None
# Message ID: <7qo8x8f517rz8fz7-ad6vkp9ebvfw0ahm-12707-fce1@nitrileanex.one>
# In Reply To: None
# References: None
# Reply To: Family Savings <Thankyou@nitrileanex.one>
# Sender: None
# Received: (qmail 410136 invoked from network); 4 Mar 2022 11:25:26 -0000
# Content Type: multipart/alternative; boundary="f01268d72645d29a4ffb4b14a6e44b8e_12707_fce1"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: 貴方は裕福で、全くお金に困ってるような方ではないかも知れませんが、今ご連絡が取れましたら、貴方に今すぐ《現金2億円》を差し上げたいと思いますので、このまま私の方まで貴方の口座情報【銀行名/支店名/口座種別/口座番号/口座名義人名】を正確に送っていただけますか？数分以内で振り込めますので時間は掛かりません。
# To: lists-djb-ezmlm@bruce-guenter.dyndns.org
# From: お知らせ <mailmaster@x2vqefck.com>
# Date: Mon, 02 Apr 2018 09:31:16 +0900
# CC: None
# BCC: None
# Message ID: <1692b7d31ec7054c0571620f882c40f5ad93577f>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 20256 invoked from network); 2 Apr 2018 00:31:18 -0000
# Content Type: text/html; charset="utf-8"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: High blood pressure GONE overnight?!
# To: bruce@untroubled.org
# From: Blood Pressure 911 <blood-pressure-911@nur7cds.com>
# Date: Sat, 22 Jan 2022 15:40:58 -0500
# CC: None
# BCC: None
# Message ID: <0.0.0.13.1D80FD05C509E82.27CA54@mail.nur7cds.com>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 711663 invoked from network); 22 Jan 2022 20:47:35 -0000
# Content Type: multipart/alternative; boundary="----=_Part_184_1126297464.1642884027815"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: この写真…何かわかる？
# To: lists-reiserfs-list@bruce-guenter.dyndns.org
# From: ★陽菜★  <kk05.01-haruna.kojikoji@rgf-129itx4r.co>
# Date: Sun, 01 May 2016 14:31:57 +0900
# CC: None
# BCC: None
# Message ID: <Xlx38GbYz1oA6j@Cv23poqit9c.com>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 19191 invoked from network); 1 May 2016 05:32:09 -0000
# Content Type: multipart/mixed; boundary="----=_Part_4964084_176803959.1462080717502"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Home security system starting at less than a $1/day w/ 36 mo. agm't. Term and install fees. Landline req'd.
# To: bruce@untroubled.org
# From: ADT Security <adt_security@binrtxz.beauty>
# Date: Mon, 16 Jan 2023 10:54:40 -0500
# CC: None
# BCC: None
# Message ID: <0.0.0.5.1D929C2D7C6708E.3EE986@mail.binrtxz.beauty>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: by mail.binrtxz.beauty id holqkc0001gf for <bruce@untroubled.org>; Mon, 16 Jan 2023 10:54:40 -0500 (envelope-from <adt_security-bruce=untroubled.org@binrtxz.beauty>)
# Content Type: multipart/alternative; boundary="----=_Part_49_880450043.1673884454428"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Best way to get slim in 2019 revealed here
# To: "bruce@untroubled.org" <bruce@untroubled.org>
# From: Product Fitness Guru <mann@Did-59.live>
# Date: Wed, 17 Apr 2019 20:04:21 -0400
# CC: None
# BCC: None
# Message ID: <xsv9MD1SXHO0foa.jyu6280614B8bsx@Did-59.live>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 4590 invoked from network); 18 Apr 2019 00:37:02 -0000
# Content Type: multipart/alternative; boundary="---=_Part_2209_35U486M95.W000ON2"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Perfect Gift For My Anyone With Knee Pain
# To: bruce@untroubled.org
# From: Knee Pain <info@spectrumallow.co>
# Date: Wed, 13 Apr 2022 09:12:12 -0500
# CC: None
# BCC: None
# Message ID:  <wPoynsjlurXNwMkHNwjhVK1Huu4Idy3I3g8Pe_V7-jQ.te2pggQL0AkolrdOs4EteLimVW2JlLUwKuh7Xj5A3QU@spectrumallow.co>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 455374 invoked from network); 13 Apr 2022 14:20:53 -0000
# Content Type: text/html; charset="ISO-8859-1"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: This ONE thing may be slowly killing you, faster.
# To: bruce@untroubled.org
# From: Get Blood Pressure 911 <get.blood.pressure.911@kohnrowak.com>
# Date: Mon, 17 Jan 2022 16:28:08 -0500
# CC: None
# BCC: None
# Message ID: <0.0.0.1E.1D80BE91F657F64.5E9A1B@mail.kohnrowak.com>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 628749 invoked from network); 17 Jan 2022 21:35:45 -0000
# Content Type: multipart/alternative; boundary="----=_Part_286_1299007371.1642454877200"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: The Season Is Changing and So Will Your Mortgage
# To: bruce@untroubled.org
# From: Mutual Of Omaha Mortgage <mutual_of_omaha_mortgage@coveyatko.com>
# Date: Sat, 19 Feb 2022 10:20:44 -0500
# CC: None
# BCC: None
# Message ID: <0.0.0.27.1D825A44388C232.36C27F@mail.coveyatko.com>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: by mail.coveyatko.com id h247h20001gi for <bruce@untroubled.org>; Sat, 19 Feb 2022 10:20:44 -0500 (envelope-from <mutual_of_omaha_mortgage-bruce=untroubled.org@coveyatko.com>)
# Content Type: multipart/alternative; boundary="----=_Part_343_1516353561.1645284020648"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: メッセージが届いてます
# To: bruce@bruce-guenter.dyndns.org
# From: お知らせ <mailmaster@wt327jp6.com>
# Date: Mon, 02 Apr 2018 19:12:15 +0900
# CC: None
# BCC: None
# Message ID: <6999af97dda81eaca73c47499954bd704f86bbd3>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 3580 invoked from network); 2 Apr 2018 10:12:18 -0000
# Content Type: text/html; charset="utf-8"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Winter Conditions Continue To Get Worst! Thermal Vest for Cold Outdoor Activities
# To: bruce@untroubled.org
# From: Jodi Garza <jodi-garza@jzeeredoubt1.shop>
# Date: Wed, 12 Jan 2022 09:21:10 -0500
# CC: None
# BCC: None
# Message ID: <0.0.0.41.1D807BFA5C33E26.3075AF@mail.jzeeredoubt1.shop>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: by mail.jzeeredoubt1.shop id hrrin60001g3 for <bruce@untroubled.org>; Wed, 12 Jan 2022 09:21:10 -0500 (envelope-from <jodi-garza-bruce=untroubled.org@jzeeredoubt1.shop>)
# Content Type: multipart/alternative; boundary="----=_Part_391_1541792617.1641996917323"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Multiple Time Casino Winner Shocks the World…Reveals All!
# To: bruce@untroubled.org
# From: Casino Winner <CasinoWinner@americanenergys.us>
# Date: Sun, 16 Jan 2022 08:05:46 -0500
# CC: None
# BCC: None
# Message ID: <w2ya6ykefzjj69zq-r1svnhlil25ssnqq-12648-35362@americanenergys.us>
# In Reply To: None
# References: None
# Reply To: Casino Winner <CasinoWinner@americanenergys.us>
# Sender: None
# Received: None
# Content Type: multipart/alternative; boundary="a05a3cff6b4cc9456d6e94eb797c8337_12648_35362"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Need To Pump Your Septic Tank? THIS Eliminates The Need For Pumping For Good
# To: bruce@untroubled.org
# From: SEPTIFIX <UsefulResorces@goldenreviv.biz>
# Date: Sat, 05 Mar 2022 06:00:28 -0800
# CC: None
# BCC: None
# Message ID: <d2rhg4x2ikp9pymo-omsinaha2ino55d8-252e-381@goldenreviv.biz>
# In Reply To: None
# References: None
# Reply To: Flushing Trick <EliminatesCorrosion@goldenreviv.biz>
# Sender: None
# Received: None
# Content Type: multipart/alternative; boundary="9c2aa9f0be843ed2ae9f939abdf90c6f_252e_381"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: We are Company which produces Eyewear
# To: lists-linux-xfs@bruce-guenter.dyndns.org
# From: Optics and Sunglasses <companyturkeyoptifabrik@gmail.com>
# Date: Fri, 30 Mar 2018 22:10:47 +0300
# CC: None
# BCC: None
# Message ID: <16d052a22fbd022cb448e380332d8d4f@gmail.com>
# In Reply To: None
# References: None
# Reply To: igememarketing@gmail.com
# Sender: None
# Received: (qmail 21958 invoked from network); 30 Mar 2018 19:11:09 -0000
# Content Type: multipart/alternative; boundary="----=SPLITOR00A_001_367940931D"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: ＞＞★祝★:完全無料受取決定＜＜
# To: lists-linux-xfs@bruce-guenter.dyndns.org
# From: info@nigh-tin-gale1820.com
# Date: Mon, 02 May 2016 13:34:08 +0900
# CC: None
# BCC: None
# Message ID: <VF7m65R9lkS3LW8yQn1P2q_i80C+uI>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 2332 invoked from network); 2 May 2016 04:34:22 -0000
# Content Type: text/plain; charset="shift_jis"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: The meaning for your existence!
# To: bruce@untroubled.org
# From: 7 Day Prayer Miracle <7DayPrayerMiracle@penisense.guru>
# Date: Tue, 12 May 2020 10:03:47 -0400
# CC: None
# BCC: None
# Message ID: <52wbb0ticxismzhv-t3qsudcsguepvdj0-ba6-14e16@penisense.guru>
# In Reply To: None
# References: None
# Reply To: Here’s The Good News <Here’sTheGoodNews@penisense.guru>
# Sender: None
# Received: None
# Content Type: multipart/alternative; boundary="9c0656b0edb345987e6ed49a9ad66348_ba6_14e16"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Today is your LUCKY DAY so find kinky Lee Sivertson
# To: Bruce <bruce@untroubled.org>
# From: Lee Sivertson <tuzutvo1987@toplinkfibra.com.br>
# Date: Fri, 25 Mar 2022 16:02:01 -0300
# CC: None
# BCC: None
# Message ID: <82BC9460.3866829@toplinkfibra.com.br>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: None
# Content Type: text/html; charset="windows-1252"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Get a Free Crispy Chicken Sandwich on us Today!
# To: bruce@untroubled.org
# From: McDonalds App <mcdonalds.app@mcd-nalds.info>
# Date: Tue, 17 Jan 2023 10:12:21 -0500
# CC: None
# BCC: None
# Message ID: <0.0.0.8.1D92A86189D89C6.42BA23@mail.mcd-nalds.info>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: by mail.mcd-nalds.info id hoquj40001gb for <bruce@untroubled.org>; Tue, 17 Jan 2023 10:12:21 -0500 (envelope-from <mcdonalds.app-bruce=untroubled.org@mcd-nalds.info>)
# Content Type: multipart/alternative; boundary="----=_Part_73_1630836562.1673968311892"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Discover Bonus Fantastic Offer
# To: Software User <bait@untroubled.org>
# From: QuickMedProvider <QuickMedDealer@neotrade.ru>
# Date: Wed, 17 Apr 2019 01:28:50 +0300
# CC: None
# BCC: None
# Message ID: <D02A793DA6725CBF63662F93879C4E7D@neotrade.ru>
# In Reply To: None
# References: None
# Reply To: QuickMedProvider <no-reply@neotrade.ru>
# Sender: None
# Received: (qmail 668 invoked by alias); 16 Apr 2019 22:47:35 -0000
# Content Type: multipart/alternative; boundary="----=_NextPart_000_050D_01D4F4BC.E9443F60"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Protect your 2nd Amendment Right and get CERTIFIED to carry today
# To: bruce@untroubled.org
# From: "Offer Usconcealedonline.com" <offer.usconcealedonlinecom@hut6630.com>
# Date: Wed, 06 May 2020 20:06:37 -0400
# CC: None
# BCC: None
# Message ID: <0.0.0.35.1D6240360A85642.1985C4@mail.hut6630.com>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 743949 invoked from network); 7 May 2020 00:12:00 -0000
# Content Type: multipart/alternative; boundary="----=_Part_478_992664990.1588809989346"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: 9170087
# To: lists-bikini@bruce-guenter.dyndns.org
# From: インフォメーション <info@x2vqefck.com>
# Date: Mon, 02 Apr 2018 11:19:57 +0900
# CC: None
# BCC: None
# Message ID: <fd90fe526ef342608147bbe2ba0d32766feb19d0>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 22795 invoked from network); 2 Apr 2018 02:19:59 -0000
# Content Type: text/html; charset="utf-8"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Your $2000 Payment Is Inside
# To: bruce@untroubled.org
# From: Robert Hawker <info@infomarkt.online>
# Date: Sun, 10 May 2020 17:33:22 +0200
# CC: None
# BCC: None
# Message ID: None
# In Reply To: None
# References: None
# Reply To: info@infomarkt.online
# Sender: None
# Received: from newtrends.site (51.75.76.56) by kundservice.store id hn49000001gq for <bruce@untroubled.org>; Mon, 11 May 2020 04:50:07 -0400 (envelope-from <noreply@infomarkt.online>)
# Content Type: multipart/alternative; charset="UTF-8"; boundary="b1_dcd36abe79e3c16931443164648f9b6a"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Does Your Bathroom Need An Update? Get A Quote Now!
# To: bruce@untroubled.org
# From: Bathroom Remodel <bathroom-remodel@elvirmosc.com>
# Date: Mon, 28 Feb 2022 15:27:55 -0500
# CC: None
# BCC: None
# Message ID: <0.0.0.41.1D82CE1AAAC958A.25386F@mail.elvirmosc.com>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 356323 invoked from network); 28 Feb 2022 20:34:00 -0000
# Content Type: multipart/alternative; boundary="----=_Part_592_1625036142.1646080063351"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Find Relief From Your Debt Today & Take Control Back of YOUR Life!
# To: bruce@untroubled.org
# From: United Debt Settlement <united.debt.settlement@cred7c.com>
# Date: Wed, 13 Apr 2022 09:42:07 -0400
# CC: None
# BCC: None
# Message ID: <0.0.0.B.1D84F3C44596754.303AB2@mail.cred7c.com>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 455010 invoked from network); 13 Apr 2022 13:52:22 -0000
# Content Type: multipart/alternative; boundary="----=_Part_103_1860889073.1649857302035"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Live  Tinnitus -Free? -
# To: "bruce@untroubled.org" <bruce@untroubled.org>
# From: Ringing Ears <david@briskigee.icu>
# Date: Sat, 06 Apr 2019 18:11:06 -0400
# CC: None
# BCC: None
# Message ID: <ltv40T85911Bdtn.atp49TKF98YFfhd@briskigee.icu>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 15527 invoked from network); 6 Apr 2019 22:42:53 -0000
# Content Type: multipart/alternative; boundary="---=_Part_7389_56Q780X75.D932LE9"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Let's get busty Minnie I. Peeler closer to Bruce and break the ice of love
# To: Bruce <bruce@untroubled.org>
# From: "Minnie I. Peeler" <trdxfame225@mobily.com.sa>
# Date: Fri, 04 Mar 2022 08:14:34 +0300
# CC: None
# BCC: None
# Message ID: <9880180C.3620356@mobily.com.sa>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: None
# Content Type: multipart/alternative; boundary="DC9891A7D559D472BAF82AE9E9D3015BD168D937"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: 私を妊娠させて下さい？
# To: lists-bikini@bruce-guenter.dyndns.org
# From: 藤沢和子 <mail@hi7miraku.net>
# Date: None
# CC: None
# BCC: None
# Message ID: <1403244487.47772681.1522633480918.JavaMail.info@hi7miraku.net>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 21987 invoked from network); 2 Apr 2018 01:44:43 -0000
# Content Type: text/plain; charset="iso-2022-jp"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Ich m�chte dich treffen
# To: Braelyn <bruce@untroubled.org>
# From: Braelyn <RyanPerry@lovess.it>
# Date: Tue, 05 May 2020 09:06:14 -0700
# CC: None
# BCC: None
# Message ID: <34639958.7AAA58D5@lovess.it>
# In Reply To: None
# References: None
# Reply To: Braelyn <RyanPerry@lovess.it>
# Sender: None
# Received: from group21.345mail.com ([167.15.155.80]) by mx03.listsystemsf.net with QMQP; Tue, 05 May 2020 09:06:14 -0700
# Content Type: text/html; charset="iso-8859-1"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Turn your phone into a 4K camera with Zoomshot Pro
# To: bruce@untroubled.org
# From: ZoomShot Pro <info@solutionbrother.co>
# Date: Fri, 25 Mar 2022 13:42:29 -0500
# CC: None
# BCC: None
# Message ID:  <SISnOZWmxAhUUXMj0V3gZ2E6ib5IQLx5K0K28tfAJJw.kbMy1alXvAUkMz68bHBxhvY6wn13ROaL3-FJXDfMigs@solutionbrother.co>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 76376 invoked from network); 25 Mar 2022 18:47:53 -0000
# Content Type: text/html; charset="ISO-8859-1"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Discover Xtra Astonishing Deals
# To: Software User <bait@untroubled.org>
# From: FastMedLabs <QuickMedUpdate@moimedportal.com>
# Date: Tue, 02 Apr 2019 01:45:58 +0300
# CC: None
# BCC: None
# Message ID: <57ADFEBA87537D9E42470EB2A6A85C64@moimedportal.com>
# In Reply To: None
# References: None
# Reply To: FastMedLabs <no-reply@moimedportal.com>
# Sender: None
# Received: (qmail 7630 invoked by alias); 1 Apr 2019 22:46:02 -0000
# Content Type: multipart/alternative; boundary="5d97e052092fff8fb0202e611c0f"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Leave your feedback and you could WIN!
# To: bruce@untroubled.org
# From: Kohl's Shopper Gift Card Chance <KohlsShopperGiftCardChance@sportyfix.us>
# Date: Sat, 05 Mar 2022 01:48:01 -0800
# CC: None
# BCC: None
# Message ID: <x1xr0i2e0u23ygc2-lrf5cmepa50f2wze-252e-381@sportyfix.us>
# In Reply To: None
# References: None
# Reply To: Customer Feedback <CustomerFeedback@sportyfix.us>
# Sender: None
# Received: None
# Content Type: multipart/alternative; boundary="35e8d8f485fb0844430934dc56b5e18f_252e_381"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: FLASH SALE! $14.99 for 16x20 Custom Canvas Prints!
# To: bruce@untroubled.org
# From: Canvas Prints Promo <canvas_prints_promo@fix4417.com>
# Date: Mon, 04 May 2020 16:56:46 -0400
# CC: None
# BCC: None
# Message ID: <0.0.0.3F.1D6225685D30BB4.1AC4D8@mail.fix4417.com>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: by mail.fix4417.com id hm21dg0001g8 for <bruce@untroubled.org>; Mon, 4 May 2020 16:56:46 -0400 (envelope-from <canvas_prints_promo-bruce=untroubled.org@fix4417.com>)
# Content Type: multipart/alternative; boundary="----=_Part_550_1480554532.1588625792455"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Asta omoara prostatita! Prostatita dispare definitiv!
# To: "bruce@untroubled.org" <bruce@untroubled.org>
# From: Urologie noutate <ramona.felicia@acsisec.com>
# Date: Mon, 15 Apr 2019 08:26:10 +0000
# CC: None
# BCC: None
# Message ID: <8319191a8b233a46654a69a3ad5ad0f6@acsisec.com>
# In Reply To: None
# References: None
# Reply To: Urologie noutate <ramona.felicia@acsisec.com>
# Sender: None
# Received: (qmail 22505 invoked from network); 15 Apr 2019 08:27:56 -0000
# Content Type: multipart/alternative; boundary="b1_8cd6cfe7499efcee8c3e68c797a8db12"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Protect Yourself this Winter Season
# To: "bruce@untroubled.org" <bruce@untroubled.org>
# From: "National Family Life (Use with Main Link)" <villarreal@Go-59.live>
# Date: Thu, 18 Apr 2019 08:44:20 -0400
# CC: None
# BCC: None
# Message ID: <sngS98DNXV69gkw.cfnB1580Y493cna@Go-59.live>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 24370 invoked from network); 18 Apr 2019 13:16:24 -0000
# Content Type: multipart/alternative; boundary="---=_Part_1898_96A099M51.D580NU1"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Are you interrupting your significant other's sleep? Here is your Snore fix!
# To: bruce@untroubled.org
# From: Stop Snoring <info@torchpalace.co>
# Date: Mon, 28 Feb 2022 05:52:56 -0500
# CC: None
# BCC: None
# Message ID:  <Sifo_s4EWKh7IxestMJ9rfYp8n_iLId5S57pSKg-yQU.gNvgA267l0z9YTLJ_vcOXWK6e-CnisQnG7UjjYYpLew@torchpalace.co>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: None
# Content Type: text/html; charset="ISO-8859-1"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: もう一度伝えるね。
# To: lists-linux-xfs@bruce-guenter.dyndns.org
# From: 優香  <s.h-y.n-0501-sabuado@av4-cz1p36.co>
# Date: Sun, 01 May 2016 16:46:27 +0900
# CC: None
# BCC: None
# Message ID: <NmHA11MKr1Wvt1PaB@PaJVJQr7Y33.com>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 24655 invoked from network); 1 May 2016 07:46:44 -0000
# Content Type: text/plain; charset="Shift_JIS"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: [ 緊急速報 ]
# To: lists-linux-kernel@bruce-guenter.dyndns.org
# From: "broyccjk@gknrlhacatllmmuyhguc.jp" <broyccjk@gknrlhacatllmmuyhguc.jp>
# Date: None
# CC: None
# BCC: None
# Message ID: None
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 3422 invoked from network); 1 Apr 2018 01:06:20 -0000
# Content Type: text/html; charset="iso-2022-jp"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Canvas Prints Ad
# To: "bruce@untroubled.org" <bruce@untroubled.org>
# From: Canvas Prints Ad <brady@b1gram.agency>
# Date: Mon, 11 May 2020 12:43:34 -0400
# CC: None
# BCC: None
# Message ID: <nihN9YBP9U68lil.mijC6I47S9B3qtq@b1gram.agency>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: None
# Content Type: multipart/alternative; boundary="---=_Part_55_523S74.CEL6"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: AMAZING LITTLE WRIST BAND STOPPED MY HUSBAND'S SNORING WHILE WEARING IT!!
# To: bruce@untroubled.org
# From: SleepConnection <info@shoutmove.co>
# Date: Tue, 26 Apr 2022 15:39:13 -0500
# CC: None
# BCC: None
# Message ID:  <6hPy5xkwoKwE9IjNrPsDz0lEJcr7TN0cJzZ6P02_XsY.K9j1KRsdsVhvZdIaEQdVh6zuq9oWrLM6VT2sY8KeKXE@shoutmove.co>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 757354 invoked from network); 26 Apr 2022 20:44:40 -0000
# Content Type: text/html; charset="ISO-8859-1"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: #1 Mask Worldwide! Why These Certified KN95 Masks Are Being Called The "The Perfect Mask"
# To: bruce@untroubled.org
# From: Protective KN95 <protective.kn95@todayschoicests6.xyz>
# Date: Tue, 01 Feb 2022 14:20:28 -0500
# CC: None
# BCC: None
# Message ID: <0.0.0.3F.1D817A0C5998124.9F693E@mail.todayschoicests6.xyz>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 975147 invoked from network); 1 Feb 2022 19:19:39 -0000
# Content Type: multipart/alternative; boundary="----=_Part_373_206467045.1643742742604"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: What's the secret to clear skin?
# To: bruce@untroubled.org
# From: Arganosa <Arganosa@prickliypear.icu>
# Date: Wed, 10 Apr 2019 06:37:58 -0400
# CC: None
# BCC: None
# Message ID: <9y99kvj0qzk082qe-qpv7co5cfe72n3nx-28-2209@prickliypear.icu>
# In Reply To: None
# References: None
# Reply To: Arganosa Oils <Arganosa@prickliypear.icu>
# Sender: None
# Received: (qmail 23873 invoked from network); 10 Apr 2019 10:39:14 -0000
# Content Type: multipart/alternative; boundary="b7c0d8b0f62cb7de4a8486d36b4a9d0e_28_2209"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Half glass water + THIS = A Smaller Belly
# To: bruce@untroubled.org
# From: Drop 12 your belly <notification+peK36nGKU0Jt7UR8n7XkNftUVJsCS8qoc@dermaannouncing.ga>
# Date: Fri, 08 May 2020 16:12:14 +0200
# CC: None
# BCC: None
# Message ID: <20191102083153.18506470.236653.4455149471346278653657@sailthru.com>
# In Reply To: None
# References: None
# Reply To: reply@dermaannouncing.ga
# Sender: None
# Received: from dermaannouncing.ga (10.68.228.107) by dermaannouncing.ga id RD9kJ2GmMwaI for <bruce@untroubled.org>; Fri, 08 May 2020 16:12:14 +0200 (envelope-from <return@dermaannouncing.ga>
# Content Type: text/html; charset="UTF-8"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: 14 Kilo in einem Monat sind hiermit kein Problem
# To: bruce@untroubled.org
# From: Hohle der Lowen <536850@united.com>
# Date: Wed, 09 Mar 2022 03:08:26 +0100
# CC: None
# BCC: None
# Message ID: None
# In Reply To: None
# References: None
# Reply To: 215221@united.com
# Sender: None
# Received: (qmail 532374 invoked from network); 9 Mar 2022 03:09:40 -0000
# Content Type: text/html; charset="UTF-8"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: RE: fast shipping services from China to your country with cheap rates
# To: bruce <bruce@untroubled.org>
# From: kenshippingagent <kenshippingagent@163.com>
# Date: Tue, 01 Mar 2022 18:32:23 +0800
# CC: None
# BCC: None
# Message ID:  <1128704677.21393675.1646130743902@shrmpr-org.mail.protection.outlook.com>
# In Reply To: None
# References: None
# Reply To: None
# Sender: peetwn <peetwn@jngijamaica.com>
# Received: None
# Content Type: text/html; charset="UTF-8"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Administracion de cuentas
# To: Recipients <exportaciones@minpal.gob.ve>
# From: Administracion de cuentas <exportaciones@minpal.gob.ve>
# Date: Thu, 11 Apr 2019 17:40:59 +0530
# CC: None
# BCC: None
# Message ID: <20190411121111.0BD6BB47810@smspyt.cancun.gob.mx>
# In Reply To: None
# References: None
# Reply To: None
# Sender: linux-kernel-owner@vger.kernel.org
# Received: (qmail 3174 invoked from network); 11 Apr 2019 12:26:57 -0000
# Content Type: text/plain; charset="iso-8859-1"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: 上手くいかない事が多く一人で悩んでいますよね？【完全無料】で相談に乗ります。
# To: lists-linux-kernel@bruce-guenter.dyndns.org
# From: recent@q3byryq3rnqvi.link
# Date: Sun, 01 May 2016 16:18:10 +0900
# CC: None
# BCC: None
# Message ID: 519339707_11666705710526913869@q3byryq3rnqvi.link
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 22951 invoked from network); 1 May 2016 07:18:13 -0000
# Content Type: text/plain; charset="Shift_JIS"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: 貴方の口座情報【銀行名/支店名/口座種別/口座番号/口座名義人名】を私に送っていただけましたら、数分以内にその口座へ《現金2億円》を振り込む事を約束します。危険なお金ではないですからね。そのお金は私個人のお金なので心配はいりません。
# To: lists-bikini@bruce-guenter.dyndns.org
# From: お知らせ <mailmaster@zp3xwecq.com>
# Date: Sun, 01 Apr 2018 08:01:49 +0900
# CC: None
# BCC: None
# Message ID: <30bf898886aaf254ba03e4333992e5dfd12b61e0>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 503 invoked from network); 31 Mar 2018 23:01:51 -0000
# Content Type: text/html; charset="utf-8"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Why Diets Fail ?
# To: bruce@untroubled.org
# From: Lose it now <loseitnow@replacelaunch.co>
# Date: Fri, 25 Feb 2022 00:22:23 -0500
# CC: None
# BCC: None
# Message ID:  <hLMkEcfsVX6Y6GJitxrpf_YIsPTItg7-3q2khchNS9M.kRzwXzcWkj99bB-0c1r2xjy9fF8buAhCfr2W_vfgBhg@replacelaunch.co>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: None
# Content Type: text/html; charset="ISO-8859-1"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Pcメールをご利用中のお客様へ
# To: lists-djb-ezmlm@bruce-guenter.dyndns.org
# From: インフォメーション <info@e4iqw3sc.com>
# Date: Sat, 31 Mar 2018 13:35:42 +0900
# CC: None
# BCC: None
# Message ID: <753f5b3d5abdcf857a21e6dae9155c87ef58f1cb>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 4404 invoked from network); 31 Mar 2018 04:35:44 -0000
# Content Type: text/html; charset="utf-8"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: The Tiny, Discreet, Extra small size Video Recorder!
# To: bruce@untroubled.org
# From: SmartCam <smartcam@medicinehard.co>
# Date: Mon, 11 Apr 2022 21:22:48 -0500
# CC: None
# BCC: None
# Message ID:  <fkvIeoBQHgAMoU56mSOjFS9W6-qfz1udVBMB2a8ZTHc.V3WzJHmFP6dF9LpVdhBuswUHyDlbLc2Wog2_cILKZBg@medicinehard.co>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: None
# Content Type: text/html; charset="ISO-8859-1"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Exclusive Rewards T-Mobile
# To: bruce@untroubled.org
# From: HumanSurveyer <SurveyRewards@memosurgee.co>
# Date: Thu, 24 Mar 2022 03:56:40 -0400
# CC: None
# BCC: None
# Message ID: <qexcr89z3c10rbxq-y4ied8p696dd197f-252e-381@memosurgee.co>
# In Reply To: None
# References: None
# Reply To: Survey Rewards <HumanSurveyer@memosurgee.co>
# Sender: None
# Received: (qmail 55006 invoked from network); 24 Mar 2022 07:56:42 -0000
# Content Type: multipart/alternative; boundary="fa61b68f2489c98d09d4c50ed885dbcb_252e_381"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: hi
# To: bgware-owner@lists.untroubled.org
# From: "garyd75@credit-cardprocessing.com" <garyd75@credit-cardprocessing.com>
# Date: Mon, 01 Apr 2019 13:54:33 -0700
# CC: None
# BCC: None
# Message ID: <0eefc296-489f-54cd-884f-10d6aa2bb9ac@credit-cardprocessing.com>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 27498 invoked from network); 1 Apr 2019 14:54:36 -0000
# Content Type: multipart/alternative; boundary="------------5EED8CD74B98765F76711702"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Wifi Booster will save you time and never experience lagging ever again.
# To: bruce@untroubled.org
# From: Wifi-UltraBoost <appraisal@meancouncil.co>
# Date: Tue, 15 Mar 2022 23:29:42 -0500
# CC: None
# BCC: None
# Message ID:  <RkonMjhtCMkjg9qiEhFYGUJ81SLdLj9_pFw64JfoV3E.R5kwDEM7ND5KU45nv0tk1sqqRVX4lP3fOgL0T0GKTik@meancouncil.co>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 132892 invoked from network); 16 Mar 2022 04:37:16 -0000
# Content Type: text/html; charset="ISO-8859-1"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Reach your target weight this year with Nutrisystem!
# To: bruce@untroubled.org
# From: Nutrisystem Discount <nutrisystem_discount@ip13hne.com>
# Date: Wed, 04 Jan 2023 10:39:34 -0500
# CC: None
# BCC: None
# Message ID: <0.0.0.45.1D92052BE95D268.766F15@mail.ip13hne.com>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: by mail.ip13hne.com id hmmfi20001gv for <bruce@untroubled.org>; Wed, 4 Jan 2023 10:39:34 -0500 (envelope-from <nutrisystem_discount-bruce=untroubled.org@ip13hne.com>)
# Content Type: multipart/alternative; boundary="----=_Part_622_336319600.1672846756277"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Advanced Knee Sleeves Provide Fast Relief at Any Age!
# To: bruce@untroubled.org
# From: Circa Knee <info@girlchoice.co>
# Date: Thu, 07 Apr 2022 16:52:30 -0500
# CC: None
# BCC: None
# Message ID:  <tB_DeCOKp5dziXLAj9O7QDJVwk9Nvh6o-4iYU7Q8gSQ.wvInX8wdR-xfvKk4rLm7OX00yOLW6DMFT1D2d_ir32o@girlchoice.co>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: None
# Content Type: text/html; charset="ISO-8859-1"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: 进出口报关l78l8858453
# To: bait@untroubled.org
# From: youshibaoguan@hotmail.com
# Date: Wed, 23 Mar 2022 15:54:17 +0800
# CC: None
# BCC: None
# Message ID: None
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: None
# Content Type: text/plain; charset="GB2312"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Hot Body Miracle Discovery
# To: bruce@untroubled.org
# From: Miracle Discovery <MiracleDiscovery@onlyhappye.bid>
# Date: Tue, 12 May 2020 07:26:55 -0400
# CC: None
# BCC: None
# Message ID: <btnqdup1inmstzbn-2nynznm2vnzgq5hc-46e4-26fb0@onlyhappye.bid>
# In Reply To: None
# References: None
# Reply To: Miracle Discovery <HotBody@onlyhappye.bid>
# Sender: None
# Received: None
# Content Type: multipart/alternative; boundary="0bb67aee8db6e5a8e367bf805fd4e2e5_46e4_26fb0"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Re: Your business cash of $250K funding can be deposited in 3 days-Qualify by 05/02/2016
# To: bruce@untroubled.org
# From: Start Up Funds <Start-Up-Funds@xearki2ni.ginfect.top>
# Date: Mon, 02 May 2016 00:28:44 -0700
# CC: None
# BCC: None
# Message ID: <0.0.f8f706c3938feec43d1f111ad3c0a047.16986687.21636135.0bruce@untroubled.org>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (fqmail 20866 invoked from network); 02 May 2016 07:29:37 -0000
# Content Type: multipart/alternative; boundary="16986687_21636135_16986687"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Your Participation is Needed!
# To: bruce@untroubled.org
# From: Thank you! CVS <notification+ClSgwZ7kXGAIJCBGBmeTG5BmOsiGvvm0u@stroved.cf>
# Date: Mon, 18 May 2020 18:38:02 +0200
# CC: None
# BCC: None
# Message ID: <20191102083153.18506470.236653.0083765703959067776446@sailthru.com>
# In Reply To: None
# References: None
# Reply To: reply@stroved.cf
# Sender: None
# Received: from stroved.cf (10.69.80.7) by stroved.cf id dCSKVMrhtbes for <bruce@untroubled.org>; Mon, 18 May 2020 18:38:02 +0200 (envelope-from <return@stroved.cf>
# Content Type: text/html; charset="UTF-8"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Your hip and low back is aching because...
# To: bruce@untroubled.org
# From: Unlock Hips <UnlockHips@aliveaftercrisis.co>
# Date: Sun, 13 Feb 2022 08:02:48 -0500
# CC: None
# BCC: None
# Message ID:  <64dltgkgy7qvsmk0-5k0sjh7u6bv2sw4s-12648-35362@aliveaftercrisis.co>
# In Reply To: None
# References: None
# Reply To: Your Pelvis <YourPelvis@aliveaftercrisis.co>
# Sender: None
# Received: None
# Content Type: multipart/alternative; boundary="88bf0130a5ebd26d0854fc39a9a62adf_12648_35362"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Attn: Are you paying for a timeshare you aren't using? 6497918
# To: bruce@untroubled.org
# From: "Kate I." <Kate.I@ceasr5tej.mathzwx.top>
# Date: Sun, 01 May 2016 23:47:51 -0700
# CC: None
# BCC: None
# Message ID: <f8f706c3938feec43d1f111ad3c0a047.6497918.11958087.Fallingbruce@untroubled.org>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (fqmail 4160 invoked from network); 02 May 2016 06:46:28 -0000
# Content Type: multipart/alternative; boundary="6497918_11958087_6497918"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Best WiFi Booster on the Market Now 50% OFF
# To: bruce@untroubled.org
# From: UltraWifiPro <ultrawifipro@frequenciestechnique.com>
# Date: Fri, 08 May 2020 12:05:13 -0400
# CC: None
# BCC: None
# Message ID: <0.0.0.6.1D6255275082072.2686F3@mail.frequenciestechnique.com>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 1806724 invoked from network); 8 May 2020 16:12:18 -0000
# Content Type: multipart/alternative; boundary="----=_Part_70_1139343145.1588953892120"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Think Of All You Could Do With Savings On Your Mortgage  Compare lenders Now!
# To: bruce@untroubled.org
# From: ChooseYourMortgage <chooseyourmortgage@hretis12.com>
# Date: Sun, 13 Feb 2022 14:23:57 -0500
# CC: None
# BCC: None
# Message ID: <0.0.0.23.1D8210F3F586DD2.69E338@mail.hretis12.com>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: by mail.hretis12.com id h15eac0001gc for <bruce@untroubled.org>; Sun, 13 Feb 2022 14:23:57 -0500 (envelope-from <chooseyourmortgage-bruce=untroubled.org@hretis12.com>)
# Content Type: multipart/alternative; boundary="----=_Part_322_1195868420.1644780222318"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Walmart Customer. Choose a $1OO Bonus for your input #21086635
# To: bruce@untroubled.org
# From: Karen Ploetz <karen_ploetz@getselectlive.click>
# Date: Tue, 12 Apr 2022 17:16:11 -0400
# CC: None
# BCC: None
# Message ID: <0.0.0.61.1D84EB28902F83C.667571@mail.getselectlive.click>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: by mail.getselectlive.click id hannji0001gb for <bruce@untroubled.org>; Tue, 12 Apr 2022 17:16:11 -0400 (envelope-from <karen_ploetz-bruce=untroubled.org@getselectlive.click>)
# Content Type: multipart/alternative; boundary="----=_Part_592_445185455.1649798150046"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: パソコン メール をご利用中のお客様へ
# To: lists-reiserfs-list@bruce-guenter.dyndns.org
# From: インフォメーション <info@y4qxnvtr.com>
# Date: Sun, 01 Apr 2018 20:52:01 +0900
# CC: None
# BCC: None
# Message ID: <8d4ba5ea6cd526bfeafbc5b7762ebe582135533c>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 20126 invoked from network); 1 Apr 2018 11:52:04 -0000
# Content Type: text/html; charset="utf-8"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: GPS Vehicle Trackers That Might Blow Your Mind
# To: bruce@untroubled.org
# From: iTrack Car <rise@dollrisk.co>
# Date: Tue, 22 Mar 2022 22:48:54 -0500
# CC: None
# BCC: None
# Message ID:  <XGdugaF5OWMer9Z307q_NKettCjJRwNBqEOn0yoedok.HtLJsxrEwsUxUDy-ramSeTAWOI-3S00UfibaOjx_TOI@dollrisk.co>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: None
# Content Type: text/html; charset="ISO-8859-1"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Seniors, you can save big
# To: bruce@untroubled.org
# From: My Senior Perks American Seniors <my-senior-perks-american-seniors@rothequisin.com>
# Date: Thu, 13 Jan 2022 14:29:09 -0500
# CC: None
# BCC: None
# Message ID: <0.0.0.30.1D808B3D63B3762.70C76@mail.rothequisin.com>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 553716 invoked from network); 13 Jan 2022 19:35:10 -0000
# Content Type: multipart/alternative; boundary="----=_Part_439_452672217.1642102133231"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: A directory for consumers to compare lenders.
# To: bruce@untroubled.org
# From: Compare W ChooseYourMortgage <compare.w.chooseyourmortgage@thaxsive.com>
# Date: Wed, 05 Jan 2022 15:32:32 -0500
# CC: None
# BCC: None
# Message ID: <0.0.0.5.1D802735DF4C390.45633@mail.thaxsive.com>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 363064 invoked from network); 5 Jan 2022 20:40:47 -0000
# Content Type: multipart/alternative; boundary="----=_Part_49_1692996197.1641414745483"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Home Warranty Coverage - 2 months free!!
# To: celestiaslo214@gmail.com
# From: Cinch Home Services <ucontactusbackplss@acrossborders.site>
# Date: Thu, 26 Jan 2023 17:09:33 +0100
# CC: None
# BCC: None
# Message ID: <_eQheVh47WErluIXjFKIcg.0@notifications.google.com>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: from google.com (google.com.  172.217.13.78)
# Content Type: text/html
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Herpes Virus Hiding Place Revealed! (Nobody Believed This!)
# To: bruce@untroubled.org
# From: Cold Sore Virus <ColdSoreVirus@diabetsastro.us>
# Date: Tue, 01 Mar 2022 08:03:17 -0500
# CC: None
# BCC: None
# Message ID: <or8hfwooug05295l-zcrokpjho52fs5ap-252e-381@diabetsastro.us>
# In Reply To: None
# References: None
# Reply To: Cold Sore Virus <ColdSoreVirus@diabetsastro.us>
# Sender: None
# Received: None
# Content Type: multipart/alternative; boundary="4fcd6b77aed70519f1f14d7f1dee7d8d_252e_381"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: RE：Rate down / Guarantee availability space and equipment ---LAX / NYC/NFC
# To: bait <bait@untroubled.org>
# From: hans <hans@realhong.com>
# Date: Sat, 12 Feb 2022 10:00:07 +0800
# CC: None
# BCC: None
# Message ID:  <1424587670.523805.1644631207781@htbbau-at0i.mail.protection.outlook.com>
# In Reply To: None
# References: None
# Reply To: None
# Sender: maosdrtzl <maosdrtzl@krammedia.com>
# Received: None
# Content Type: text/html; charset="UTF-8"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: None
# To: None
# From: Men's Breakthrough <BluoxynRiskFree@thegod.guru>
# Date: Wed, 13 May 2020 09:53:25 -0400
# CC: None
# BCC: None
# Message ID: None
# In Reply To: None
# References: None
# Reply To: Bluoxyn Risk Free <Men'sBreakthrough@thegod.guru>
# Sender: None
# Received: None
# Content Type: multipart/alternative; boundary="b51a321ad5791318a820d70a8050981e_ba6_14e16"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: BONUS: $50 AMAZON Gift Card Opportunity
# To: bruce@untroubled.org
# From: Amazon Opinion Requested <AmazonShopperGiftCardChance@aliveaftercrisis.co>
# Date: Tue, 26 Apr 2022 05:54:22 -0400
# CC: None
# BCC: None
# Message ID: <3dleclbymeyuk4z1-v5lgbumrio228s4r-12707-fce1@aliveaftercrisis.co>
# In Reply To: None
# References: None
# Reply To: Amazon Shopper Gift Opportunity <AmazonShopperFeedback@aliveaftercrisis.co>
# Sender: None
# Received: None
# Content Type: multipart/alternative; boundary="750c19d5d08d03d5e5b33c820d60cab7_12707_fce1"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: メッセージが届いてます
# To: lists-bikini@bruce-guenter.dyndns.org
# From: お知らせ <mailmaster@zp3xwecq.com>
# Date: Sun, 01 Apr 2018 07:10:39 +0900
# CC: None
# BCC: None
# Message ID: <8d30a2c21bd12fd5322f7d799c1c83a633e8b805>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 31733 invoked from network); 31 Mar 2018 22:10:41 -0000
# Content Type: text/html; charset="utf-8"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Involved in an Auto Accident? Talk to an Expert
# To: celestiaslo214@gmail.com
# From: AutoAccidentTeam <ucontactusbackplss@acrossborders.site>
# Date: Thu, 26 Jan 2023 17:47:01 +0100
# CC: None
# BCC: None
# Message ID: <_eQheVh47WErluIXjFKIcg.0@notifications.google.com>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: from google.com (google.com.  172.217.13.78)
# Content Type: text/html
# Content Encoding: None
# Content Disposition: None
#
#
# Subject:  2022年11月の新対策解析済み！全額返金保証！現在全ch視聴可能！
# To: bruce@untroubled.org
# From: 2022年11月の新Key解析済み！ <mail@nb76yt54h68.click>
# Date: Tue, 17 Jan 2023 12:29:05 +0900
# CC: None
# BCC: None
# Message ID: <20230117122905@cur.wvlhbzmhmq>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: from localhost (unknown [10.190.73.81])	by 7EhYsw.0fzAzN7B5 (Postfix) with ESMTP id 870DC1049159	for <bruce@untroubled.org>; Tue, 17 Jan 2023 12:29:05 +0900 (JST)
# Content Type: text/plain; charset="Shift_JIS"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: hi
# To: bgware-owner@lists.untroubled.org
# From: "jasond03@creditbootcamp.com" <jasond03@creditbootcamp.com>
# Date: Sun, 14 Apr 2019 18:44:45 -0700
# CC: None
# BCC: None
# Message ID: <51665a2f-7383-c9f3-f5f5-b530b2160059@creditbootcamp.com>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 26699 invoked from network); 14 Apr 2019 19:44:48 -0000
# Content Type: multipart/alternative; boundary="------------988F5D52440B81CD11E75883"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: やば’いです！早く！’連絡がない…...
# To: cvs@bruce-guenter.dyndns.org
# From: infopc2@r9s.k1hrgcrnu.com
# Date: Mon, 02 May 2016 10:40:40 +0900
# CC: None
# BCC: None
# Message ID: <mqNCs.9HVeyR@qUY4C0.Mv0Su1>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 30397 invoked from network); 2 May 2016 01:40:17 -0000
# Content Type: text/plain; charset="Shift_JIS"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: BREAKING: New Pain Pill From Japan Now Available in the US
# To: "bruce@untroubled.org" <bruce@untroubled.org>
# From: Legendary Ventures <spencer@visitclan.live>
# Date: Wed, 10 Apr 2019 17:06:19 -0400
# CC: None
# BCC: None
# Message ID: <wswWISJ72PD2eqn.yjhHGB6HSI9Ydqi@visitclan.live>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 12463 invoked from network); 10 Apr 2019 21:38:14 -0000
# Content Type: multipart/alternative; boundary="---=_Part_6116_75N505G13.Z972TM0"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Don't turn back from UNREAD MESSAGE of Barbaraanne T.
# To: Bruce <bruce@untroubled.org>
# From: "Barbaraanne T." <flztconstancy@victoriarealty.info>
# Date: Tue, 01 Mar 2022 14:42:26 +0300
# CC: None
# BCC: None
# Message ID: <B7904E7F.049105@simbanet.co.ug>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: None
# Content Type: text/html; charset="utf-8"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Your guests are thirsty! Order more wine
# To: bruce@untroubled.org
# From: TopRated Wines Splash Wines <toprated.wines.splash.wines@rvioes.beauty>
# Date: Fri, 06 Jan 2023 10:32:55 -0500
# CC: None
# BCC: None
# Message ID: <0.0.0.12.1D921E425C4EC2A.5D5EFE@mail.rvioes.beauty>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 216271 invoked from network); 6 Jan 2023 15:39:32 -0000
# Content Type: multipart/alternative; boundary="----=_Part_166_1309027409.1673019140873"
# Content Encoding: None
# Content Disposition: None
#
#
# Subject: Order BlueChew - Safe, Secure, Discreet.
# To: bruce@untroubled.org
# From: Custom Medical Group <custom.medical.group@sidblogmaster.com>
# Date: Thu, 14 May 2020 04:05:04 -0700
# CC: None
# BCC: None
# Message ID: <0.0.0.3.1D629DF851DD056.49E6E7@mail.sidblogmaster.com>
# In Reply To: None
# References: None
# Reply To: None
# Sender: None
# Received: (qmail 2321800 invoked from network); 14 May 2020 11:12:36 -0000
# Content Type: multipart/alternative; boundary="----=_Part_28_455119019.1589454290078"
# Content Encoding: None
# Content Disposition: None
